# %%
import requests
from bs4 import BeautifulSoup
import unicodedata
import pandas as pd

# %%
Falcon9_WikiURL= "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"

# %%
site= requests.get(Falcon9_WikiURL)

# %%
site.status_code
# Out:
# 200

# %%
site.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-me
# ...

# %%
soup= BeautifulSoup(site.text , 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>
# ...

# %%
soup.title
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %%
X= soup.find_all("table")
#3rd table
X[2]
# Out:
# <table class="wikitable" style="width:100%; font-size:1.00em; line-height:1.5em;">
# <tbody><tr class="is-sticky">
# <th scope="col" style="width: 10%;">Date and time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)<sup class="reference" id="cite_ref-nextSFupcoming_400-1"><a href="#cite_note-nextSFupcoming-400"><span class="cite-bracket">[</span>392<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_23-2"><a href="#cite_note-booster-23"><span class="cite-bracket">[</span>c<span class="cite-bracket">]</span></a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_24-2"><a href="#cite_note-Dragon-24"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup>
# </th>
# ...

# %%
X1= soup.find_all("th", {"scope" : "col"})
X1
#X= soup.find("div", {"class":"s-main-slot s-result-list s-search-results sg-row"})
# Out:
# [<th scope="col">Flight No.
#  </th>,
#  <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
#  </th>,
#  <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_23-0"><a href="#cite_note-booster-23"><span class="cite-bracket">[</span>c<span class="cite-bracket">]</span></a></sup>
#  </th>,
#  <th scope="col">Launch<br/>site
#  </th>,
#  <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_24-0"><a href="#cite_note-Dragon-24"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup>
#  </th>,
#  <th scope="col">Payload mass
#  </th>,
#  <th scope="col">Orbit
#  </th>,
#  <th scope="col">Customer
#  </th>,
#  <th scope="col">Launch<br/>outcome
#  </th>,
# ...

# %%
#column_name=[]

#for i in first_launch_table.find_all('th'):
    #if extract_column_from_header(i)!- None:
       # in len (extract_column_from_header(i))>0:
           # column_name.append(extract_column_from_header(i))

# %%
len(X1)
# Out:
# 41

# %%
len(X)
# Out:
# 15

# %%
column_name=[]

for i in range (41):
    column_name.append(X1[i])

# %%
column_name
# Out:
# [<th scope="col">Flight No.
#  </th>,
#  <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
#  </th>,
#  <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_23-0"><a href="#cite_note-booster-23"><span class="cite-bracket">[</span>c<span class="cite-bracket">]</span></a></sup>
#  </th>,
#  <th scope="col">Launch<br/>site
#  </th>,
#  <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_24-0"><a href="#cite_note-Dragon-24"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup>
#  </th>,
#  <th scope="col">Payload mass
#  </th>,
#  <th scope="col">Orbit
#  </th>,
#  <th scope="col">Customer
#  </th>,
#  <th scope="col">Launch<br/>outcome
#  </th>,
# ...

# %%
import pandas as pd

# Assuming 'column_name' is your list with potentially mixed types
df = pd.DataFrame({'column_name': column_name})
print(df)
# Out:
#                                           column_name
# 0                                      [Flight No.\n]
# 1                  [Date and, [], time (, [UTC], )\n]
# 2   [[Version,, [], booster], [[<span class="cite-...
# 3                                [Launch, [], site\n]
# 4   [Payload, [[<span class="cite-bracket">[</span...
# 5                                    [Payload mass\n]
# 6                                           [Orbit\n]
# 7                                        [Customer\n]
# 8                             [Launch, [], outcome\n]
# 9                        [[Booster, [], landing], \n]
# 10                           [[], Flight, [],  No.\n]
# 11                 [Date and, [], time (, [UTC], )\n]
# 12  [[Version,, [], booster], [[<span class="cite-...
# 13                               [Launch, [], site\n]
# 14  [Payload, [[<span class="cite-bracket">[</span...
# 15                                   [Payload mass\n]
# ...

# %%
df
# Out:
#                                           column_name
# 0                                      [Flight No.\n]
# 1                  [Date and, [], time (, [UTC], )\n]
# 2   [[Version,, [], booster], [[<span class="cite-...
# 3                                [Launch, [], site\n]
# 4   [Payload, [[<span class="cite-bracket">[</span...
# 5                                    [Payload mass\n]
# 6                                           [Orbit\n]
# 7                                        [Customer\n]
# 8                             [Launch, [], outcome\n]
# 9                        [[Booster, [], landing], \n]
# 10                           [[], Flight, [],  No.\n]
# 11                 [Date and, [], time (, [UTC], )\n]
# 12  [[Version,, [], booster], [[<span class="cite-...
# 13                               [Launch, [], site\n]
# 14  [Payload, [[<span class="cite-bracket">[</span...
# 15                                   [Payload mass\n]
# ...

# %%
launch_dict= dict.fromkeys(column_name)

# %%
launch_dict
# Out:
# {<th scope="col">Flight No.
#  </th>: None,
#  <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
#  </th>: None,
#  <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_23-0"><a href="#cite_note-booster-23"><span class="cite-bracket">[</span>c<span class="cite-bracket">]</span></a></sup>
#  </th>: None,
#  <th scope="col">Launch<br/>site
#  </th>: None,
#  <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_24-0"><a href="#cite_note-Dragon-24"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup>
#  </th>: None,
#  <th scope="col">Payload mass
#  </th>: None,
#  <th scope="col">Orbit
#  </th>: None,
#  <th scope="col">Customer
#  </th>: None,
#  <th scope="col">Launch<br/>outcome
#  </th>: None,
# ...

# %%
#del lunch_dic['Date']

# %%
#lunch_dic['flight No'] = []
